# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv')
df = df.drop(columns=['Unnamed: 0'], axis=1)
df
# Out:
#                                                  Name  ... Other_Sales
# 0                        Candace Kane's Candy Factory  ...           0
# 1                                      The Munchables  ...        0.01
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable  ...           0
# 3                    Deal or No Deal: Special Edition  ...           0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction  ...        0.04
# ...                                               ...  ...         ...
# 16593                         Ice Age 2: The Meltdown  ...        0.01
# 16594                     Rainbow Islands: Revolution  ...           0
# 16595                                        NBA 2K16  ...        0.13
# 16596                     Toukiden: The Age of Demons  ...        0.03
# 16597                        The King of Fighters '95  ...        0.01
#
# [16598 rows x 9 columns]

# %%
#def sales_to_float(x):
#    if type(x) == float or type(x) == int:
#        return x
#    if 'K' in x:
#        return float(x.replace('K', '')) * 0.001
#    if 'M' in x:
#        return float(x.replace('M', ''))



def sales_to_float(x):
    if 'K' in x:
            return float(x.replace('K', '')) * 0.001
    elif 'M' in x:
            return float(x.replace('M', ''))
    else:
      return float(x)

df['NA_Sales'] = df['NA_Sales'].apply(sales_to_float)
df['EU_Sales'] = df['EU_Sales'].apply(sales_to_float)
df['JP_Sales'] = df['JP_Sales'].apply(sales_to_float)
df['Other_Sales'] = df['Other_Sales'].apply(sales_to_float)
df
# Out:
#                                                  Name  ... Other_Sales
# 0                        Candace Kane's Candy Factory  ...        0.00
# 1                                      The Munchables  ...        0.01
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable  ...        0.00
# 3                    Deal or No Deal: Special Edition  ...        0.00
# 4           Ben 10 Ultimate Alien: Cosmic Destruction  ...        0.04
# ...                                               ...  ...         ...
# 16593                         Ice Age 2: The Meltdown  ...        0.01
# 16594                     Rainbow Islands: Revolution  ...        0.00
# 16595                                        NBA 2K16  ...        0.13
# 16596                     Toukiden: The Age of Demons  ...        0.03
# 16597                        The King of Fighters '95  ...        0.01
#
# [16598 rows x 9 columns]

# %%
df['Global_Sales'] = df['NA_Sales'] + df['EU_Sales'] + df['JP_Sales'] + df['Other_Sales']

# %%
df.loc[[50], ['Genre']] = df.loc[[50], ['Genre']].fillna('Platform')
df.loc[[408], ['Genre']] = df.loc[[408], ['Genre']].fillna('Sports')
df.loc[[1328], ['Genre']] = df.loc[[1328], ['Genre']].fillna('Sports')
df.loc[[1582], ['Genre']] = df.loc[[1582], ['Genre']].fillna('Action')
df.loc[[1971], ['Genre']] = df.loc[[1971], ['Genre']].fillna('Role-Playing')
df.loc[[2043], ['Genre']] = df.loc[[2043], ['Genre']].fillna('Racing')
df.loc[[2497], ['Genre']] = df.loc[[2497], ['Genre']].fillna('Action')
df.loc[[3353], ['Genre']] = df.loc[[3353], ['Genre']].fillna('Adventure')
df.loc[[3363], ['Genre']] = df.loc[[3363], ['Genre']].fillna('Sports')
df.loc[[3470], ['Genre']] = df.loc[[3470], ['Genre']].fillna('Action')
df.loc[[3515], ['Genre']] = df.loc[[3515], ['Genre']].fillna('Adventure')
df.loc[[3932], ['Genre']] = df.loc[[3932], ['Genre']].fillna('Sports')
df.loc[[4148], ['Genre']] = df.loc[[4148], ['Genre']].fillna('Adventure')
df.loc[[4349], ['Genre']] = df.loc[[4349], ['Genre']].fillna('Puzzle')
df.loc[[4545], ['Genre']] = df.loc[[4545], ['Genre']].fillna('Fighting')
df.loc[[4598], ['Genre']] = df.loc[[4598], ['Genre']].fillna('Misc')
df.loc[[4935], ['Genre']] = df.loc[[4935], ['Genre']].fillna('Role-Playing')
df.loc[[5668], ['Genre']] = df.loc[[5668], ['Genre']].fillna('Role-Playing')
df.loc[[5713], ['Genre']] = df.loc[[5713], ['Genre']].fillna('Adventure')
df.loc[[5945], ['Genre']] = df.loc[[5945], ['Genre']].fillna('Adventure')
df.loc[[6798], ['Genre']] = df.loc[[6798], ['Genre']].fillna('Role-Playing')
df.loc[[7143], ['Genre']] = df.loc[[7143], ['Genre']].fillna('Action')
df.loc[[7336], ['Genre']] = df.loc[[7336], ['Genre']].fillna('Sports')
df.loc[[7526], ['Genre']] = df.loc[[7526], ['Genre']].fillna('Action')
df.loc[[7797], ['Genre']] = df.loc[[7797], ['Genre']].fillna('Puzzle')
df.loc[[9488], ['Genre']] = df.loc[[9488], ['Genre']].fillna('Role-Playing')
df.loc[[10432], ['Genre']] = df.loc[[10432], ['Genre']].fillna('Adventure')
df.loc[[10501], ['Genre']] = df.loc[[10501], ['Genre']].fillna('Misc')
df.loc[[10874], ['Genre']] = df.loc[[10874], ['Genre']].fillna('Simulation')
df.loc[[11050], ['Genre']] = df.loc[[11050], ['Genre']].fillna('Misc')
df.loc[[11063], ['Genre']] = df.loc[[11063], ['Genre']].fillna('Action')
df.loc[[11268], ['Genre']] = df.loc[[11268], ['Genre']].fillna('Adventure')
df.loc[[11496], ['Genre']] = df.loc[[11496], ['Genre']].fillna('Racing')
df.loc[[11668], ['Genre']] = df.loc[[11668], ['Genre']].fillna('Shooter')
df.loc[[11699], ['Genre']] = df.loc[[11699], ['Genre']].fillna('Fighting')
df.loc[[12314], ['Genre']] = df.loc[[12314], ['Genre']].fillna('Sports')
df.loc[[12331], ['Genre']] = df.loc[[12331], ['Genre']].fillna('Fighting')
df.loc[[12340], ['Genre']] = df.loc[[12340], ['Genre']].fillna('Simulation')
df.loc[[12870], ['Genre']] = df.loc[[12870], ['Genre']].fillna('Puzzle')
df.loc[[12982], ['Genre']] = df.loc[[12982], ['Genre']].fillna('Action')
df.loc[[13348], ['Genre']] = df.loc[[13348], ['Genre']].fillna('Puzzle')
df.loc[[14930], ['Genre']] = df.loc[[14930], ['Genre']].fillna('Action')
df.loc[[15077], ['Genre']] = df.loc[[15077], ['Genre']].fillna('Racing')
df.loc[[15211], ['Genre']] = df.loc[[15211], ['Genre']].fillna('Shooter')
df.loc[[15426], ['Genre']] = df.loc[[15426], ['Genre']].fillna('Misc')
df.loc[[15526], ['Genre']] = df.loc[[15526], ['Genre']].fillna('Role-Playing')
df.loc[[16091], ['Genre']] = df.loc[[16091], ['Genre']].fillna('Puzzle')
df.loc[[16431], ['Genre']] = df.loc[[16431], ['Genre']].fillna('Racing')
df.loc[[16555], ['Genre']] = df.loc[[16555], ['Genre']].fillna('Action')
df.loc[[16587], ['Genre']] = df.loc[[16587], ['Genre']].fillna('Racing')

# %%
df = df.dropna(axis=0)

# %%
def year(x):
  if (x >= 0) & (x < 20):
    return int(2000 + x)
  elif (x > 30) & (x < 1000):
    return int(1900 + x)
  else:
    return int(x)

df['Year'] = df['Year'].apply(year)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                                  Name  ... Global_Sales
# 0                        Candace Kane's Candy Factory  ...         0.04
# 1                                      The Munchables  ...         0.18
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable  ...         0.02
# 3                    Deal or No Deal: Special Edition  ...         0.04
# 4           Ben 10 Ultimate Alien: Cosmic Destruction  ...         0.25
# ...                                               ...  ...          ...
# 16593                         Ice Age 2: The Meltdown  ...         0.20
# ...

# %%
df.dtypes
# Out:
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df_genre = df.groupby(by=['Genre'])['Global_Sales'].sum() # 전 대륙 선호하는 게임 장르
df_genre = df_genre.reset_index()

df_genre_na = df.groupby(by=['Genre'])['NA_Sales'].sum() # 북미 선호하는 게임 장르
df_genre_na = df_genre_na.reset_index()

df_genre_eu = df.groupby(by=['Genre'])['EU_Sales'].sum() # 유럽 선호하는 게임 장르
df_genre_eu = df_genre_eu.reset_index()

df_genre_jp = df.groupby(by=['Genre'])['JP_Sales'].sum() # 일본 선호하는 게임 장르
df_genre_jp = df_genre_jp.reset_index()

df_genre_ot = df.groupby(by=['Genre'])['Other_Sales'].sum() # 일본 선호하는 게임 장르
df_genre_ot = df_genre_ot.reset_index()

df_genre = df_genre.combine_first(df_genre_na).combine_first(df_genre_eu).combine_first(df_genre_jp).combine_first(df_genre_ot)
df_genre = df_genre.set_index("Genre")



plt.figure(figsize=(15, 10))
plt.title("Regional Preference of Game Genre", fontsize=30)
plt.xlabel("Genre", fontsize=15)
plt.ylabel("Sales", fontsize=15)

sns.lineplot(data=df_genre, markers=True);

# %%
year_sale_dx = df.groupby(by=['Year', 'Genre'])['Global_Sales'].sum().reset_index()
year_sale = year_sale_dx.groupby(by=['Year'])['Global_Sales'].transform(max) == year_sale_dx['Global_Sales']
year_sale_max = year_sale_dx[year_sale].reset_index(drop=True)

genre = year_sale_max['Genre']

plt.figure(figsize=(50, 40))
g = sns.barplot(x='Year', y='Global_Sales', data=year_sale_max)
index = 0
for value in year_sale_max['Global_Sales']:
    g.text(index, value + 1, str(genre[index] + '-' +str(round(value, 2))), color='#000', size=20, rotation= 90, ha="center")
    index += 1

plt.title("Yearly game trends", fontsize=30)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Global Sales", fontsize=20)

plt.xticks(rotation=90)
plt.show()

# %%
sortdf = df.sort_values(by=['Global_Sales'], ascending=False)
top_game_sale = sortdf.head(10)
top_game_sale = top_game_sale[['Name','Platform', 'Publisher', 'Year', 'Genre', 'Global_Sales']]
top_game_sale = top_game_sale.sort_values(by=['Global_Sales'], ascending=False)
top_game_sale = top_game_sale.reset_index(drop=True)
top_game_sale
# Out:
#                         Name Platform  ...         Genre  Global_Sales
# 0                 Wii Sports      Wii  ...        Sports         82.74
# 1          Super Mario Bros.      NES  ...      Platform         40.24
# 2             Mario Kart Wii      Wii  ...        Racing         35.83
# 3          Wii Sports Resort      Wii  ...        Sports         33.00
# 4   Pokemon Red/Pokemon Blue       GB  ...  Role-Playing         31.38
# 5                     Tetris       GB  ...        Puzzle         30.26
# 6      New Super Mario Bros.       DS  ...      Platform         30.01
# 7                   Wii Play      Wii  ...          Misc         29.01
# 8  New Super Mario Bros. Wii      Wii  ...      Platform         28.61
# 9                  Duck Hunt      NES  ...       Shooter         28.31
#
# [10 rows x 6 columns]

# %%
df_first_sales = df[df['Name'] == 'Wii Sports']
df_first_sales = df_first_sales.drop(['Year'], axis=1)
sns.set(style='darkgrid')
plt.figure(figsize=(15, 10))
plt.title("Regional Sales of Wii Sports", fontsize=30)
plt.xlabel("Region", fontsize=20)
plt.ylabel("Sales", fontsize=20)

sns.barplot(data=df_first_sales);
